# %% [markdown]
# <a href="https://colab.research.google.com/github/Beckyyy07/Imersao-Python-Alura/blob/main/Imersao-Python-Alura%20/Aula%203/Imers%C3%A3o_Python_Alura_Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# Importando arquivos

# %%
df_principal = pd.read_excel("/content/Tabela de ações pura.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
df_totalAcoes = pd.read_excel("/content/Tabela de ações pura.xlsx", sheet_name="Total_de_acoes")
df_totalAcoes
# Out:
#                       Código     Qtde. Teórica
# 0                      RRRP3    235,665,566.00
# 1                      ALOS3    532,616,595.00
# 2                      ALPA4    176,733,968.00
# 3                      ABEV3  4,394,245,879.00
# 4                      ARZZ3     62,305,891.00
# ..                       ...               ...
# 84                     VBBR3  1,114,412,532.00
# 85                     WEGE3  1,481,593,024.00
# 86                     YDUQ3    289,347,914.00
# 87  Quantidade Teórica Total 96,372,098,181.00
# 88                   Redutor     17,047,850.79
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Tabela de ações pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Tabela de ações pura.xlsx", sheet_name="chatGPT")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade (em anos)
# 0           Usiminas         Siderurgia               60
# 1      CSN Mineração          Mineração               30
# 2          Petrobras           Petróleo               68
# 3             Suzano   Papel e Celulose              100
# 4       CPFL Energia            Energia              108
# ..               ...                ...              ...
# 75  Carrefour Brasil             Varejo               47
# 76       Casas Bahia             Varejo               67
# 77          Localiza  Aluguel de Carros               48
# 78               CVC            Turismo               49
# 79               GOL   Transporte Aéreo               21
#
# [80 rows x 3 columns]

# %% [markdown]
# Atualizando o data frame apenas com as colunas que iremos utilizar

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
#  Renomeando colunas último (R$) e Var. Dia (%)

# %%
df_principal = df_principal.rename(columns = {'Último (R$)': 'valorFinal','Var. Dia (%)': 'variacaoDiaPCT'}).copy()
df_principal
# Out:
#     Ativo       Data  valorFinal  variacaoDiaPCT
# 0   USIM5 2024-01-26        9.50            5.20
# 1   CMIN3 2024-01-26        6.82            2.40
# 2   PETR3 2024-01-26       41.96            2.19
# 3   SUZB3 2024-01-26       52.91            2.04
# 4   CPFE3 2024-01-26       37.10            2.03
# ..    ...        ...         ...             ...
# 76  CRFB3 2024-01-26       10.71           -2.45
# 77  BHIA3 2024-01-26        8.70           -2.46
# 78  RENT3 2024-01-26       56.24           -3.63
# 79  CVCB3 2024-01-26        3.07           -4.36
# 80  GOLL4 2024-01-26        5.92           -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
# Criando coluna de variação do dia em porcentagem (variacao_pct)

# %%
df_principal['variacao_pct'] = df_principal['variacaoDiaPCT']/100
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct
# 0  USIM5 2024-01-26        9.50            5.20          0.05
# 1  CMIN3 2024-01-26        6.82            2.40          0.02
# 2  PETR3 2024-01-26       41.96            2.19          0.02
# 3  SUZB3 2024-01-26       52.91            2.04          0.02
# 4  CPFE3 2024-01-26       37.10            2.03          0.02

# %% [markdown]
# Criando a coluna 'VALOR INICIAL'

# %%
df_principal['valorInicial'] = df_principal['valorFinal'] / (df_principal['variacao_pct'] + 1)
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36

# %% [markdown]
# Criando coluna Quantidade de ações (qntd_acoes)

# %%
df_principal = df_principal.merge(df_totalAcoes, left_on= 'Ativo', right_on = 'Código', how='left')
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#   Código    Qtde. Teórica
# 0  USIM5   515,117,391.00
# 1  CMIN3 1,110,559,345.00
# 2  PETR3 2,379,877,655.00
# 3  SUZB3   683,452,836.00
# 4  CPFE3   187,732,538.00

# %% [markdown]
# Removendo coluna código (duplicidade de valores)

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#      Qtde. Teórica
# 0   515,117,391.00
# 1 1,110,559,345.00
# 2 2,379,877,655.00
# 3   683,452,836.00
# 4   187,732,538.00

# %% [markdown]
# Criando coluna (Variação dia ($))

# %%
df_principal['VariacaoDiaEmReais'] = (df_principal['valorFinal'] - df_principal['valorInicial']) * df_principal['Qtde. Teórica']
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#      Qtde. Teórica  VariacaoDiaEmReais
# 0   515,117,391.00      241,889,725.43
# 1 1,110,559,345.00      177,515,970.30
# 2 2,379,877,655.00    2,140,059,393.53
# 3   683,452,836.00      722,946,282.71
# 4   187,732,538.00      138,573,955.06

# %% [markdown]
# Transformando floats (números decimais) para duas casas decimais

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#    Qtde. Teórica  VariacaoDiaEmReais
# 0   515117391.00        241889725.43
# 1  1110559345.00        177515970.30
# 2  2379877655.00       2140059393.53
# 3   683452836.00        722946282.71
# 4   187732538.00        138573955.06

# %% [markdown]
# Criando coluna Resultado (Subiu, Desceu, Estável)

# %%
df_principal['Resultado'] = pd.Series(['SUBIU' if x > 0 else 'ESTÁVEL' if x == 0 else 'DESCEU' for x in df_principal['VariacaoDiaEmReais']])
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado
# 0   515117391.00        241889725.43     SUBIU
# 1  1110559345.00        177515970.30     SUBIU
# 2  2379877655.00       2140059393.53     SUBIU
# 3   683452836.00        722946282.71     SUBIU
# 4   187732538.00        138573955.06     SUBIU

# %% [markdown]
# Criando coluna (Nome da empresa)

# %%
df_principal = df_principal.merge(df_ticker, left_on= 'Ativo', right_on = 'Ticker', how='left')
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado Ticker           Nome
# 0   515117391.00        241889725.43     SUBIU  USIM5       Usiminas
# 1  1110559345.00        177515970.30     SUBIU  CMIN3  CSN Mineração
# 2  2379877655.00       2140059393.53     SUBIU  PETR3      Petrobras
# 3   683452836.00        722946282.71     SUBIU  SUZB3         Suzano
# 4   187732538.00        138573955.06     SUBIU  CPFE3   CPFL Energia

# %% [markdown]
# Removendo coluna Ticker (duplicidade de valor)

# %%
df_principal = df_principal.drop(columns=['Ticker'])
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 4  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado           Nome
# 0   515117391.00        241889725.43     SUBIU       Usiminas
# 1  1110559345.00        177515970.30     SUBIU  CSN Mineração
# 2  2379877655.00       2140059393.53     SUBIU      Petrobras
# 3   683452836.00        722946282.71     SUBIU         Suzano
# 4   187732538.00        138573955.06     SUBIU   CPFL Energia

# %% [markdown]
# Adicionando colunas Idade, cat_Idade, Segmento

# %%
df_principal = df_principal.merge(df_chatgpt, left_on= 'Nome', right_on = 'Nome da Empresa', how='left')
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado           Nome Nome da Empresa  \
# 0   515117391.00        241889725.43     SUBIU       Usiminas        Usiminas
# 1  1110559345.00        177515970.30     SUBIU  CSN Mineração   CSN Mineração
# 2  2379877655.00       2140059393.53     SUBIU      Petrobras       Petrobras
# 3  2379877655.00       2140059393.53     SUBIU      Petrobras       Petrobras
# 4   683452836.00        722946282.71     SUBIU         Suzano          Suzano
#
#            Segmento  Idade (em anos)
# ...

# %%
df_principal = df_principal.drop(columns = ['Nome da Empresa'])
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado           Nome  \
# 0   515117391.00        241889725.43     SUBIU       Usiminas
# 1  1110559345.00        177515970.30     SUBIU  CSN Mineração
# 2  2379877655.00       2140059393.53     SUBIU      Petrobras
# 3  2379877655.00       2140059393.53     SUBIU      Petrobras
# 4   683452836.00        722946282.71     SUBIU         Suzano
#
#            Segmento  Idade (em anos)
# 0        Siderurgia               60
# 1         Mineração               30
# ...

# %%
df_principal = df_principal.rename(columns = {'Idade (em anos)': 'Idade'}).copy()
df_principal.head(5)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado           Nome  \
# 0   515117391.00        241889725.43     SUBIU       Usiminas
# 1  1110559345.00        177515970.30     SUBIU  CSN Mineração
# 2  2379877655.00       2140059393.53     SUBIU      Petrobras
# 3  2379877655.00       2140059393.53     SUBIU      Petrobras
# 4   683452836.00        722946282.71     SUBIU         Suzano
#
#            Segmento  Idade
# 0        Siderurgia     60
# 1         Mineração     30
# 2          Petróleo     68
# ...

# %%
df_principal['categoria_idade'] = pd.Series(['MAIS DE CEM ANOS' if x > 100 else 'MENOS DE 50 ANOS' if x < 50 else 'ENTRE 50 E 100 ANOS' for x in df_principal['Idade']])
df_principal.head(10)
# Out:
#    Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0  USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1  CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3  PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4  SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 5  CPFE3 2024-01-26       37.10            2.03          0.02         36.36
# 6  PRIO3 2024-01-26       45.69            1.98          0.02         44.80
# 7  PETR4 2024-01-26       39.96            1.73          0.02         39.28
# 8  PETR4 2024-01-26       39.96            1.73          0.02         39.28
# 9  VALE3 2024-01-26       69.50            1.66          0.02         68.37
#
#    Qtde. Teórica  VariacaoDiaEmReais Resultado           Nome  \
# 0   515117391.00        241889725.43     SUBIU       Usiminas
# ...

# %% [markdown]
# (Qtde. Teórica) de float para int (número inteiro)

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0   USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1   CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4   SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# ..    ...        ...         ...             ...           ...           ...
# 80  CRFB3 2024-01-26       10.71           -2.45         -0.02         10.98
# 81  BHIA3 2024-01-26        8.70           -2.46         -0.02          8.92
# 82  RENT3 2024-01-26       56.24           -3.63         -0.04         58.36
# 83  CVCB3 2024-01-26        3.07           -4.36         -0.04          3.21
# 84  GOLL4 2024-01-26        5.92           -8.07         -0.08          6.44
#
# ...

# %%
df_principal = df_principal.rename(columns = {'Qtde. Teórica': 'qntdAcoes'}).copy()
df_principal
# Out:
#     Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0   USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1   CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 3   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4   SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# ..    ...        ...         ...             ...           ...           ...
# 80  CRFB3 2024-01-26       10.71           -2.45         -0.02         10.98
# 81  BHIA3 2024-01-26        8.70           -2.46         -0.02          8.92
# 82  RENT3 2024-01-26       56.24           -3.63         -0.04         58.36
# 83  CVCB3 2024-01-26        3.07           -4.36         -0.04          3.21
# 84  GOLL4 2024-01-26        5.92           -8.07         -0.08          6.44
#
# ...

# %%
df_principal = df_principal.drop_duplicates()
df_principal
# Out:
#     Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0   USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1   CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4   SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 5   CPFE3 2024-01-26       37.10            2.03          0.02         36.36
# ..    ...        ...         ...             ...           ...           ...
# 80  CRFB3 2024-01-26       10.71           -2.45         -0.02         10.98
# 81  BHIA3 2024-01-26        8.70           -2.46         -0.02          8.92
# 82  RENT3 2024-01-26       56.24           -3.63         -0.04         58.36
# 83  CVCB3 2024-01-26        3.07           -4.36         -0.04          3.21
# 84  GOLL4 2024-01-26        5.92           -8.07         -0.08          6.44
#
# ...

# %% [markdown]
# #Análises

# %%
maior = df_principal['VariacaoDiaEmReais'].max()
idmaior = df_principal['VariacaoDiaEmReais'].idxmax()
empresaMaior = df_principal.loc[idmaior, 'Nome']
print(f"A empresa que mais subiu foi a {empresaMaior} com R${maior}")
# Out:
# A empresa que mais subiu foi a Vale com R$4762926995.24809

# %%
menor = df_principal['VariacaoDiaEmReais'].min()
idmenor = df_principal['VariacaoDiaEmReais'].idxmin()
empresamenor = df_principal.loc[idmenor, 'Nome']
print(f"A empresa que mais desceu foi a {empresamenor} com  R${menor}")
# Out:
# A empresa que mais desceu foi a Localiza com  R$-1807432634.4595425

# %%
qntdTotal = df_principal['Resultado'].count()
mediaTotal = df_principal['VariacaoDiaEmReais'].mean()
print(f'Média de todas as empresas foi de: R${mediaTotal}')
print(qntdTotal)
# Out:
# Média de todas as empresas foi de: R$165190210.47934026
# 81

# %%
qntdSubiu = df_principal[df_principal['Resultado'] == 'SUBIU']['VariacaoDiaEmReais'].count()
mediaSubiu = df_principal[df_principal['Resultado'] == 'SUBIU']['VariacaoDiaEmReais'].mean()
print(f'Quantidade das empresas que subiram é de {qntdSubiu}. E média dessas empresas: {mediaSubiu}')
# Out:
# Quantidade das empresas que subiram é de 44. E média dessas empresas: 448164250.23049796

# %%
qntdDesceu = df_principal[df_principal['Resultado'] == 'DESCEU']['VariacaoDiaEmReais'].count()
mediaDesceu = df_principal[df_principal['Resultado'] == 'DESCEU']['VariacaoDiaEmReais'].mean()
print(f'Quantidade das empresas que subiram é de {qntdDesceu}. E média dessas empresas: {mediaDesceu}')
# Out:
# Quantidade das empresas que subiram é de 35. E média dessas empresas: -181109141.75186712

# %% [markdown]
# Criando data frame para mostrar apenas dados das empresas que subiram

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'SUBIU']
df_principal_subiu
# Out:
#     Ativo       Data  valorFinal  variacaoDiaPCT  variacao_pct  valorInicial  \
# 0   USIM5 2024-01-26        9.50            5.20          0.05          9.03
# 1   CMIN3 2024-01-26        6.82            2.40          0.02          6.66
# 2   PETR3 2024-01-26       41.96            2.19          0.02         41.06
# 4   SUZB3 2024-01-26       52.91            2.04          0.02         51.85
# 5   CPFE3 2024-01-26       37.10            2.03          0.02         36.36
# 6   PRIO3 2024-01-26       45.69            1.98          0.02         44.80
# 7   PETR4 2024-01-26       39.96            1.73          0.02         39.28
# 9   VALE3 2024-01-26       69.50            1.66          0.02         68.37
# 10  MULT3 2024-01-26       28.19            1.58          0.02         27.75
# 11  ITUB4 2024-01-26       32.81            1.48          0.01         32.33
# 12  RDOR3 2024-01-26       27.56            1.43          0.01         27.17
# ...

# %% [markdown]
# Criando data frame para mostrar apenas dados por segmento

# %%
df_segmento = df_principal_subiu.groupby('Segmento')['VariacaoDiaEmReais'].sum().reset_index()
pd.options.display.float_format = '{:,.2f}'.format
df_segmento
# Out:
#                   Segmento  VariacaoDiaEmReais
# 0                Alimentos      407,833,683.09
# 1             Combustíveis      388,705,223.96
# 2         Construção Civil       37,525,872.38
# 3                 Educação       72,295,838.99
# 4                  Energia      821,116,399.61
# 5                  Holding      416,092,244.42
# 6   Instituição Financeira    3,740,512,018.78
# 7                Logística        4,131,341.16
# 8                Mineração    4,940,442,965.55
# 9         Papel e Celulose      722,946,282.71
# 10            Petroquímica       69,054,317.64
# 11                Petróleo    6,093,288,832.26
# 12                   Saúde      453,917,907.01
# 13    Serviços Financeiros       43,657,683.38
# 14          Serviços de TI       18,068,446.61
# 15        Shopping Centers      117,732,680.08
# 16              Siderurgia      489,935,930.93
# 17              Tecnologia       15,598,886.65
# 18        Telecomunicações      292,938,114.42
# ...

# %% [markdown]
# Criando data frame para fazer uma análise por saldo

# %%
df_saldo = df_principal.groupby('Resultado')['VariacaoDiaEmReais'].sum().reset_index()
pd.options.display.float_format = '{:,.2f}'.format
df_saldo
# Out:
#   Resultado  VariacaoDiaEmReais
# 0    DESCEU   -6,338,819,961.32
# 1   ESTÁVEL                0.00
# 2     SUBIU   19,719,227,010.14

# %%
fig_varDia = px.bar(df_saldo, x='Resultado', y='VariacaoDiaEmReais', text='VariacaoDiaEmReais', title='Variação diária R$')
fig_varDia.update_layout(width = 700)
fig_varDia.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # DESAFIOS DA AULA

# %% [markdown]
# 1.   Pesquise com a documentação da biblioteca Plotly exibir os número do gráfico de forma mais visível, com a pontuação correta
# 2.   Fazer o gráfico de pizza no df_analise_segmento com a mesma biblioteca Plotly
# 3.   Fazer o GroupBy da categoria de idades e gerar o gráfico de barras

# %%
#1 - Pesquise com a documentação da biblioteca Plotly exibir os número do gráfico de forma mais visível, com a pontuação correta
# update_traces(texttemplate='%{text:,.2f}',hovertemplate='%{y:,.2f} Reais')

# %%
#2 - Fazer o gráfico de pizza no df_analise_segmento com a mesma biblioteca Plotly
df_segmento
# Out:
#                   Segmento  VariacaoDiaEmReais
# 0                Alimentos      407,833,683.09
# 1             Combustíveis      388,705,223.96
# 2         Construção Civil       37,525,872.38
# 3                 Educação       72,295,838.99
# 4                  Energia      821,116,399.61
# 5                  Holding      416,092,244.42
# 6   Instituição Financeira    3,740,512,018.78
# 7                Logística        4,131,341.16
# 8                Mineração    4,940,442,965.55
# 9         Papel e Celulose      722,946,282.71
# 10            Petroquímica       69,054,317.64
# 11                Petróleo    6,093,288,832.26
# 12                   Saúde      453,917,907.01
# 13    Serviços Financeiros       43,657,683.38
# 14          Serviços de TI       18,068,446.61
# 15        Shopping Centers      117,732,680.08
# 16              Siderurgia      489,935,930.93
# 17              Tecnologia       15,598,886.65
# 18        Telecomunicações      292,938,114.42
# ...

# %%
fig_variacaoPorSegmento = px.pie(df_segmento, values='VariacaoDiaEmReais', names='Segmento')
fig_variacaoPorSegmento
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#3 - Fazer o GroupBy da categoria de idades e gerar o gráfico de barras

df_idade = df_principal.groupby('categoria_idade')['VariacaoDiaEmReais'].sum().reset_index()
pd.options.display.float_format = '{:,.2f}'.format
df_idade
# Out:
#        categoria_idade  VariacaoDiaEmReais
# 0  ENTRE 50 E 100 ANOS   11,691,071,628.20
# 1     MAIS DE CEM ANOS      971,377,356.50
# 2     MENOS DE 50 ANOS      717,958,064.12

# %%
fig_varIdade = px.bar(df_idade, x='categoria_idade', y='VariacaoDiaEmReais', text='VariacaoDiaEmReais', title='Variação diária por tempo de existência R$')
fig_varIdade.update_traces(texttemplate='%{text:,.2f}',hovertemplate='%{y:,.2f} Reais')
fig_varIdade.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
